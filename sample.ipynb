# %% [markdown]
# ![image.png](attachment:d3e076df-97e1-485d-8caa-d4a16a517673.png)

# %% [markdown]
# # Guorong Ji and Brandon Chen
# # FRE-6103 MP2

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# # Methodology
